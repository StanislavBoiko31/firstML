# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(train_labels[i])
plt.show( )

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
from keras import models
from keras import layers
# Визначення типу моделі
network = models.Sequential()
# Визначення прихованого шару
network.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation='softmax'))
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
network.compile (optimizer = 'rmsprop', loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
network.fit(train_images, train_labels, epochs = 6, batch_size = 128)
# Out:
# Epoch 1/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8715 - loss: 0.4467
# Epoch 2/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9651 - loss: 0.1195
# Epoch 3/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9786 - loss: 0.0744
# Epoch 4/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9854 - loss: 0.0491
# Epoch 5/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9881 - loss: 0.0384
# Epoch 6/6
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9925 - loss: 0.0272

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9775 - loss: 0.0709

# %%
network.save('my_model.keras')

# %%
from keras.models import load_model
model = load_model('my_model.keras')

# %%
import cv2
import numpy as np

# Назви зображень
images = ['four.png', 'one.png', 'six.png', 'two.png', 'seven.png']

for name in images:
    # Читання зображення у відтінках сірого
    original = cv2.imread(name, 0)

    # Зміна кольору на зворотній
    modified = cv2.bitwise_not(original)

    # Приведення розміру до 28x28
    resized_img = cv2.resize(modified, (28, 28))

    # Підготовка до передбачення
    vector = resized_img.flatten().astype('float32') / 255
    vector = vector.reshape(1, -1)

    # Отримання передбачення
    output = model.predict(vector)[0]
    result = np.argmax(output)

    # Вивід результату
    print(f"{name} -> Модель визначила: {result}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# four.png -> Модель визначила: 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# one.png -> Модель визначила: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# six.png -> Модель визначила: 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# two.png -> Модель визначила: 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# seven.png -> Модель визначила: 7

# %% [markdown]
# # Завдання 2

# %%
from keras.src.datasets import mnist, cifar10, fashion_mnist
(train_images_2, train_labels_2), (test_images_2, test_labels_2) = cifar10.load_data()

# %%
category_names = ['plane','car','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images_2[i], cmap=plt.cm.binary)
    plt.xlabel(category_names[int(train_labels_2[i].item())])
plt.show( )

# %%
train_images_2 = train_images_2.astype('float32') / 255
test_images_2 = test_images_2.astype('float32') / 255

# %%
#cifar1 = models.Sequential([
 #   Input(shape = (32, 32, 3)),
  #  layers.Flatten(),
   # layers.Dense(256, activation = 'relu'),
    #layers.Dense(128, activation = 'relu'),
    #layers.Dense(10, activation = 'softmax')
#])

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import BatchNormalization, Dropout
cifar2 = models.Sequential([
    Input(shape=(32, 32, 3)),
    
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    Dropout(0.25),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    Dropout(0.25),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

# %%
def show_acc(model_2, test_images_2, test_labels_2):
    model_2.compile(optimizer=Adam(learning_rate=1e-3),
                    loss='sparse_categorical_crossentropy',
                    metrics=['accuracy'])
    history = model_2.fit(train_images_2, train_labels_2,
                          epochs=10, batch_size=64, validation_split=0.2)

    test_loss, test_acc = model_2.evaluate(test_images_2, test_labels_2)
    print(f"Точність на тестових даних: {test_acc:.4f}")

    # Графіки
    plt.plot(history.history['accuracy'], label='Train accuracy')
    plt.plot(history.history['val_accuracy'], label='Val accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(); plt.grid(True); plt.show()

    plt.plot(history.history['loss'], label='Train loss')
    plt.plot(history.history['val_loss'], label='Val loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(); plt.grid(True); plt.show()

# %%
from tensorflow.keras.optimizers import Adam
show_acc(cifar2, test_images_2, test_labels_2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 42ms/step - accuracy: 0.3697 - loss: 1.9800 - val_accuracy: 0.3896 - val_loss: 1.7428
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.5564 - loss: 1.2479 - val_accuracy: 0.5930 - val_loss: 1.1466
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.6153 - loss: 1.0910 - val_accuracy: 0.5720 - val_loss: 1.2218
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.6413 - loss: 1.0214 - val_accuracy: 0.5975 - val_loss: 1.1689
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.6583 - loss: 0.9705 - val_accuracy: 0.6605 - val_loss: 0.9467
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.6797 - loss: 0.9139 - val_accuracy: 0.6868 - val_loss: 0.8995
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.6928 - loss: 0.8724 - val_accuracy: 0.6944 - val_loss: 0.8722
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.7035 - loss: 0.8489 - val_accuracy: 0.6336 - val_loss: 1.0469
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.7088 - loss: 0.8201 - val_accuracy: 0.7060 - val_loss: 0.8510
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 41ms/step - accuracy: 0.7227 - loss: 0.7908 - val_accuracy: 0.7163 - val_loss: 0.8110
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7220 - loss: 0.8085
# Точність на тестових даних: 0.7139

# %%
# Збереження моделі
cifar2.save("cifar10_model.keras")

# %%
from tensorflow.keras.models import load_model

# Завантаження збереженої моделі
model_3 = load_model("cifar10_model.keras")

# %%
# Список файлів, які хочеш перевірити
filenames = ["truck.png", "horse.png", "bird.png", "deer.png", "ship.png", "ship2.png", "frog1.png", "frog2.png", "plane.png", ]  # додай свої файли

# Перевірка кожного файлу
for filename in filenames:
    # Завантаження і підготовка
    img = cv2.imread(filename)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img, (32, 32))
    img_array = img_resized.astype("float32") / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Прогноз
    pred = model_3.predict(img_array)
    predicted_label = category_names[np.argmax(pred)]

    # Вивід
    print(f"Файл {filename} - Модель розпізнала: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Файл truck.png - Модель розпізнала: truck
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Файл horse.png - Модель розпізнала: horse
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Файл bird.png - Модель розпізнала: frog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Файл deer.png - Модель розпізнала: deer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Файл ship.png - Модель розпізнала: ship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Файл ship2.png - Модель розпізнала: ship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Файл frog1.png - Модель розпізнала: frog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Файл frog2.png - Модель розпізнала: frog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Файл plane.png - Модель розпізнала: plane

# %% [markdown]
# # Завдання 3

# %%
from keras.datasets import fashion_mnist
(train_images_3, train_labels_3), (test_images_3, test_labels_3) = fashion_mnist.load_data()

# %%
# Назви категорій
category_names_fmnist = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                         'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Візуалізація
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([]); plt.yticks([]); plt.grid(False)
    plt.imshow(train_images_3[i], cmap=plt.cm.binary)
    plt.xlabel(category_names_fmnist[train_labels_3[i]])
plt.show()

# %%
# Підготовка зображень
train_images_3 = train_images_3.reshape((60000, 28, 28, 1)).astype("float32") / 255
test_images_3 = test_images_3.reshape((10000, 28, 28, 1)).astype("float32") / 255

# %%
# Побудова моделі
from tensorflow.keras import models, layers
from tensorflow.keras.layers import BatchNormalization, Dropout, Input
from tensorflow.keras.optimizers import Adam

fmnist_model = models.Sequential([
    Input(shape=(28, 28, 1)),

    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    Dropout(0.25),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    Dropout(0.25),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

# %%
# Навчання та оцінка
def show_acc_fmnist(model, test_images, test_labels):
    model.compile(optimizer=Adam(learning_rate=1e-3),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    history = model.fit(train_images_3, train_labels_3,
                        epochs=20, batch_size=64, validation_split=0.2)

    test_loss, test_acc = model.evaluate(test_images, test_labels)
    print(f"Точність на тестових даних: {test_acc:.4f}")

    # Графіки
    plt.plot(history.history['accuracy'], label='Train accuracy')
    plt.plot(history.history['val_accuracy'], label='Val accuracy')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.grid(True); plt.legend()
    plt.show()

    plt.plot(history.history['loss'], label='Train loss')
    plt.plot(history.history['val_loss'], label='Val loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.grid(True); plt.legend()
    plt.show()

# %%
# Виклик функції навчання
show_acc_fmnist(fmnist_model, test_images_3, test_labels_3)
# Out:
# Epoch 1/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 26s 32ms/step - accuracy: 0.7653 - loss: 0.7100 - val_accuracy: 0.8836 - val_loss: 0.3264
# Epoch 2/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - accuracy: 0.8755 - loss: 0.3494 - val_accuracy: 0.8971 - val_loss: 0.2741
# Epoch 3/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.8888 - loss: 0.3112 - val_accuracy: 0.9042 - val_loss: 0.2592
# Epoch 4/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.8955 - loss: 0.2907 - val_accuracy: 0.9133 - val_loss: 0.2378
# Epoch 5/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.9048 - loss: 0.2658 - val_accuracy: 0.9105 - val_loss: 0.2418
# Epoch 6/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - accuracy: 0.9042 - loss: 0.2589 - val_accuracy: 0.9159 - val_loss: 0.2329
# Epoch 7/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.9108 - loss: 0.2444 - val_accuracy: 0.9057 - val_loss: 0.2637
# Epoch 8/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.9168 - loss: 0.2311 - val_accuracy: 0.9215 - val_loss: 0.2208
# Epoch 9/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.9175 - loss: 0.2289 - val_accuracy: 0.9088 - val_loss: 0.2551
# Epoch 10/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.9214 - loss: 0.2137 - val_accuracy: 0.9138 - val_loss: 0.2398
# Epoch 11/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.9225 - loss: 0.2137 - val_accuracy: 0.8959 - val_loss: 0.2909
# Epoch 12/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.9261 - loss: 0.2072 - val_accuracy: 0.9098 - val_loss: 0.2448
# Epoch 13/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.9280 - loss: 0.1984 - val_accuracy: 0.9230 - val_loss: 0.2202
# Epoch 14/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.9264 - loss: 0.1995 - val_accuracy: 0.9252 - val_loss: 0.2030
# Epoch 15/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.9299 - loss: 0.1916 - val_accuracy: 0.9302 - val_loss: 0.1966
# Epoch 16/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 25s 33ms/step - accuracy: 0.9304 - loss: 0.1891 - val_accuracy: 0.9327 - val_loss: 0.1925
# Epoch 17/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.9357 - loss: 0.1785 - val_accuracy: 0.9280 - val_loss: 0.2106
# Epoch 18/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - accuracy: 0.9352 - loss: 0.1720 - val_accuracy: 0.9221 - val_loss: 0.2124
# Epoch 19/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - accuracy: 0.9363 - loss: 0.1725 - val_accuracy: 0.9268 - val_loss: 0.2088
# Epoch 20/20
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 24s 32ms/step - accuracy: 0.9332 - loss: 0.1790 - val_accuracy: 0.9318 - val_loss: 0.1981
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9288 - loss: 0.2264
# Точність на тестових даних: 0.9266

# %%
# Збереження моделі
fmnist_model.save("fashion_mnist_model.keras")

# %%
# Завантаження і перевірка зовнішніх зображень
from tensorflow.keras.models import load_model
import cv2
import numpy as np

model_fmnist_loaded = load_model("fashion_mnist_model.keras")

# Приклади зображень
filenames_fmnist = ["bag.png", "t-shirt.png", "pullover.png", "sandal.png"]  # додай свої

for filename in filenames_fmnist:
    img = cv2.imread(filename, 0)
    img_resized = cv2.resize(img, (28, 28))
    img_normalized = img_resized.astype("float32") / 255.0
    img_ready = np.expand_dims(img_normalized, axis=(0, -1))  # (1, 28, 28, 1)

    pred = model_fmnist_loaded.predict(img_ready)
    predicted_label = category_names_fmnist[np.argmax(pred)]

    print(f"Файл {filename} - Модель розпізнала: {predicted_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Файл bag.png - Модель розпізнала: Bag
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Файл t-shirt.png - Модель розпізнала: Shirt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Файл pullover.png - Модель розпізнала: Shirt
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Файл sandal.png - Модель розпізнала: Shirt
